# %% [markdown]
# ## Решение практической задачи 3
#
# ### Задача: Поиск подходящего коллеги по работе (младшего коллеги либо старшего коллеги)
#
# <center>
#     <img src="https://raw.githubusercontent.com/aimclub/OCEANAI/main/docs/source/user_guide/notebooks/images/Step_1_get_scores_ru.svg" width="60%"/>
# </center>
#
# <center>
#     <img src="https://raw.githubusercontent.com/aimclub/OCEANAI/main/docs/source/user_guide/notebooks/images/Step_2_task_3_ru.svg" width="60%"/>
# </center>
#
# <hr>

# %%
import os  # Взаимодействие с файловой системой
import sys # Доступ к некоторым переменным и функциям Python

PATH_TO_SOURCE = os.path.abspath(os.path.dirname(globals()['_dh'][0]))
PATH_TO_ROOT = os.path.join(PATH_TO_SOURCE, '..', '..', '..')

sys.path.insert(0, os.path.abspath(PATH_TO_ROOT))

# %% [markdown]
# ### `FI V2`

# %%
# Импорт необходимых инструментов
import os
import pandas as pd

# Импорт модуля
from oceanai.modules.lab.build import Run

# Создание экземпляра класса
_b5 = Run()

# Настройка ядра
_b5.path_to_save_ = './models' # Директория для сохранения файла
_b5.chunk_size_ = 2000000      # Размер загрузки файла из сети за 1 шаг

corpus = 'fi'

# Формирование аудиомоделей
res_load_model_hc = _b5.load_audio_model_hc()
res_load_model_nn = _b5.load_audio_model_nn()

# Загрузка весов аудиомоделей
url = _b5.weights_for_big5_['audio'][corpus]['hc']['sberdisk']
res_load_model_weights_hc = _b5.load_audio_model_weights_hc(url = url)

url = _b5.weights_for_big5_['audio'][corpus]['nn']['sberdisk']
res_load_model_weights_nn = _b5.load_audio_model_weights_nn(url = url)

# Формирование видеомоделей
res_load_model_hc = _b5.load_video_model_hc(lang='en')
res_load_model_deep_fe = _b5.load_video_model_deep_fe()
res_load_model_nn = _b5.load_video_model_nn()

# Загрузка весов видеомоделей
url = _b5.weights_for_big5_['video'][corpus]['hc']['sberdisk']
res_load_model_weights_hc = _b5.load_video_model_weights_hc(url = url)

url = _b5.weights_for_big5_['video'][corpus]['fe']['sberdisk']
res_load_model_weights_deep_fe = _b5.load_video_model_weights_deep_fe(url = url)

url = _b5.weights_for_big5_['video'][corpus]['nn']['sberdisk']
res_load_model_weights_nn = _b5.load_video_model_weights_nn(url = url)

# Загрузка словаря с экспертными признаками (текстовая модальность)
res_load_text_features = _b5.load_text_features()

# Формирование текстовых моделей 
res_setup_translation_model = _b5.setup_translation_model() # только для русского языка
res_setup_translation_model = _b5.setup_bert_encoder(force_reload = False)
res_load_text_model_hc_fi = _b5.load_text_model_hc(corpus=corpus)
res_load_text_model_nn_fi = _b5.load_text_model_nn(corpus=corpus)

# Загрузка весов текстовых моделей
url = _b5.weights_for_big5_['text'][corpus]['hc']['sberdisk']
res_load_text_model_weights_hc_fi = _b5.load_text_model_weights_hc(url = url)

url = _b5.weights_for_big5_['text'][corpus]['nn']['sberdisk']
res_load_text_model_weights_nn_fi = _b5.load_text_model_weights_nn(url = url)

# Формирование модели для мультимодального объединения информации
res_load_avt_model_b5 = _b5.load_avt_model_b5()

# Загрузка весов модели для мультимодального объединения информации
url = _b5.weights_for_big5_['avt'][corpus]['b5']['sberdisk']
res_load_avt_model_weights_b5 = _b5.load_avt_model_weights_b5(url = url)

PATH_TO_DIR = './video_FI/'
PATH_SAVE_VIDEO = './video_FI/test/'

_b5.path_to_save_ = PATH_SAVE_VIDEO

# Загрузка 10 тестовых аудиовидеозаписей из корпуса First Impression V2
# URL: https://chalearnlap.cvc.uab.cat/dataset/24/description/
domain = 'https://download.sberdisk.ru/download/file/'
tets_name_files = [
    '429713680?token=FqHdMLSSh7zYSZt&filename=_plk5k7PBEg.003.mp4',
    '429713681?token=Hz9b4lQkrLfic33&filename=be0DQawtVkE.002.mp4',
    '429713683?token=EgUXS9Xs8xHm5gz&filename=2d6btbaNdfo.000.mp4',
    '429713684?token=1U26753kmPYdIgt&filename=300gK3CnzW0.003.mp4',
    '429713685?token=LyigAWLTzDNwKJO&filename=300gK3CnzW0.001.mp4',
    '429713686?token=EpfRbCKHyuc4HPu&filename=cLaZxEf1nE4.004.mp4',
    '429713687?token=FNTkwqBr4jOS95l&filename=g24JGYuT74A.004.mp4',
    '429713688?token=qDT95nz7hfm2Nki&filename=JZNMxa3OKHY.000.mp4',
    '429713689?token=noLguEGXDpbcKhg&filename=nvlqJbHk_Lc.003.mp4',
    '429713679?token=9L7RQ0hgdJlcek6&filename=4vdJGgZpj4k.003.mp4'
]

for curr_files in tets_name_files:
    _b5.download_file_from_url(url = domain + curr_files, out = True)

# Получение прогнозов
_b5.path_to_dataset_ = PATH_TO_DIR # Директория набора данных
_b5.ext_ = ['.mp4'] # Расширения искомых файлов

# Полный путь к файлу с верными предсказаниями для подсчета точности
url_accuracy = _b5.true_traits_[corpus]['sberdisk']

_b5.get_avt_predictions(url_accuracy = url_accuracy, lang = 'en')
# Out:
# <span style="color:#666">**[</span><span style="color:#1776D2">2023-12-10 13:54:23</span><span style="color:#666">]</span> <span style="color:#666">Извлечение признаков (экспертных и нейросетевых) из текста ...</span>**
# <span style="color:#666">**[</span><span style="color:#1776D2">2023-12-10 13:54:24</span><span style="color:#666">]</span> <span style="color:#666">Получение прогнозов и вычисление точности (мультимодальное объединение) ...</span>**<p><span style="color:#666">&nbsp;&nbsp;&nbsp;&nbsp;10 из 10 (100.0%) ... GitHub\OCEANAI\docs\source\user_guide\notebooks\video_FI\test\_plk5k7PBEg.003.mp4 ...</span></p>
#                                                  Path  Openness  \
# ID
# 1   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.581176
# 2   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.463994
# 3   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.454372
# 4   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...   0.58854
# 5   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.633406
# 6   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.637029
# 7   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.531662
# 8   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.610325
# 9   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.495769
# 10  D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.606943
#
#    Conscientiousness Extraversion Agreeableness Neuroticism
# ID
# 1           0.628883     0.466608      0.622235    0.553782
# 2           0.418886     0.412943      0.493443     0.42311
# 3           0.414889     0.391971      0.485117    0.420733
# 4            0.64328     0.530884      0.603118    0.593453
# 5           0.533096     0.523775       0.60854    0.588395
# 6           0.542368     0.558452      0.570962    0.559017
# 7           0.376999     0.393284      0.490555    0.447986
# 8           0.541385     0.563141      0.595067    0.569522
# 9           0.458488      0.41441      0.469163    0.435409
# 10          0.591744     0.520519      0.603848    0.565598
# <span style="color:#666">**[</span><span style="color:#1776D2">2023-12-10 13:54:24</span><span style="color:#666">]</span> <span style="color:#666">Точность по отдельным персональным качествам личности человека ...</span>**
#           Openness  Conscientiousness  Extraversion  Agreeableness  \
# Metrics
# MAE         0.0589             0.0612        0.0863         0.0697
# Accuracy    0.9411             0.9388        0.9137         0.9303
#
#           Neuroticism    Mean
# Metrics
# MAE            0.0583  0.0669
# Accuracy       0.9417  0.9331
# <span style="color:#666">**[</span><span style="color:#1776D2">2023-12-10 13:54:24</span><span style="color:#666">]</span> <span style="color:#666">Средняя средних абсолютных ошибок: <span style="color:#1776D2">0.0669</span>, средняя точность: <span style="color:#1776D2">0.9331</span> ...</span>**
# <span style="color:#008001">**Лог файлы успешно сохранены ...**</span>
# <span style="color:#666">**--- Время выполнения: 42.278 сек. ---**</span>
# True

# %% [markdown]
# <hr>
#
# Для поиска подходящего коллеги по работе необходимо знать по два коэффициента корреляции для каждого персонального качества личности человека. Эти коэффициенты должны показывать как изменится оценка качества одного человека, если она будет больше или меньше оценки качества другого человека.
#
# В качестве примера предлагается использование коэффициентов корреляции между двумя людьми в контексте отношений "начальник-подчиненный", представленных в статье:
#
# 1) Kuroda S., Yamamoto I. Good boss, bad boss, workers’ mental health and productivity: Evidence from Japan // Japan & The World Economy. – 2018. – vol. 48. – pp. 106-118.
#
# Пользователь может установит свои коэффициенты корреляции.

# %%
# Загрузка датафрейма с коэффициентами корреляции
url = 'https://download.sberdisk.ru/download/file/476587839?token=o0LhzNQ5pqaoGPh&filename=colleague_ranking.csv'
df_correlation_coefficients = pd.read_csv(url)
df_correlation_coefficients = pd.DataFrame(
    df_correlation_coefficients.drop(['ID'], axis = 1)
)

df_correlation_coefficients.index.name = 'ID'
df_correlation_coefficients.index += 1
df_correlation_coefficients.index = df_correlation_coefficients.index.map(str)

df_correlation_coefficients
# Out:
#    Score_comparison  Openness  Conscientiousness  Extraversion  Agreeableness  \
# ID
# 1            higher   -0.0602             0.0471       -0.1070        -0.0832
# 2             lower   -0.1720            -0.1050        0.0772         0.0703
#
#     Neuroticism
# ID
# 1         0.190
# 2        -0.229

# %% [markdown]
# #### Поиск старшего коллеги

# %%
# Список оценок персональных качеств личности целевого человека
target_scores = [0.527886, 0.522337, 0.458468, 0.51761, 0.444649]

_b5._colleague_ranking(
    correlation_coefficients = df_correlation_coefficients,
    target_scores = target_scores,
    colleague = 'major',
    equal_coefficients = 0.5,
    out = False
)

_b5._save_logs(df = _b5.df_files_colleague_, name = 'colleague_ranking', out = True)

_b5.df_files_colleague_
# Out:
#                                                  Path  Openness  \
# ID
# 7   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.531662
# 4   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...   0.58854
# 1   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.581176
# 10  D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.606943
# 5   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.633406
# 8   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.610325
# 6   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.637029
# 3   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.454372
# 2   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.463994
# 9   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.495769
#
#    Conscientiousness Extraversion Agreeableness Neuroticism     Match
# ID
# 7           0.376999     0.393284      0.490555    0.447986  0.078373
# 4            0.64328     0.530884      0.603118    0.593453  0.000624
# 1           0.628883     0.466608      0.622235    0.553782 -0.001830
# 10          0.591744     0.520519      0.603848    0.565598 -0.007180
# 5           0.533096     0.523775       0.60854    0.588395 -0.007898
# 8           0.541385     0.563141      0.595067    0.569522 -0.012826
# 6           0.542368     0.558452      0.570962    0.559017 -0.013844
# 3           0.414889     0.391971      0.485117    0.420733 -0.153658
# 2           0.418886     0.412943      0.493443     0.42311 -0.154147
# 9           0.458488      0.41441      0.469163    0.435409 -0.168141

# %% [markdown]
# #### Поиск младшего коллеги

# %%
# Список оценок персональных качеств личности целевого человека
target_scores = [0.527886, 0.522337, 0.458468, 0.51761, 0.444649]

_b5._colleague_ranking(
    correlation_coefficients = df_correlation_coefficients,
    target_scores = target_scores,
    colleague = 'minor',
    equal_coefficients = 0.5,
    out = False
)

_b5._save_logs(df = _b5.df_files_colleague_, name = 'colleague_ranking', out = True)

_b5.df_files_colleague_
# Out:
#                                                  Path  Openness  \
# ID
# 9   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.495769
# 3   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.454372
# 2   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.463994
# 8   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.610325
# 6   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.637029
# 1   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.581176
# 10  D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.606943
# 5   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.633406
# 4   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...   0.58854
# 7   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.531662
#
#    Conscientiousness Extraversion Agreeableness Neuroticism     Match
# ID
# 9           0.458488      0.41441      0.469163    0.435409 -0.008919
# 3           0.414889     0.391971      0.485117    0.420733 -0.010205
# 2           0.418886     0.412943      0.493443     0.42311 -0.013045
# 8           0.541385     0.563141      0.595067    0.569522 -0.206910
# 6           0.542368     0.558452      0.570962    0.559017 -0.211339
# 1           0.628883     0.466608      0.622235    0.553782 -0.213027
# 10          0.591744     0.520519      0.603848    0.565598 -0.213370
# 5           0.533096     0.523775       0.60854    0.588395 -0.216435
# 4            0.64328     0.530884      0.603118    0.593453 -0.221212
# 7           0.376999     0.393284      0.490555    0.447986 -0.259188

# %% [markdown]
# ### `MuPTA` (ru)

# %%
import os
import pandas as pd

# Импорт модуля
from oceanai.modules.lab.build import Run

# Создание экземпляра класса
_b5 = Run()

corpus = 'mupta'
lang = 'ru'

# Настройка ядра
_b5.path_to_save_ = './models' # Директория для сохранения файла
_b5.chunk_size_ = 2000000      # Размер загрузки файла из сети за 1 шаг

# Формирование аудиомоделей
res_load_model_hc = _b5.load_audio_model_hc()
res_load_model_nn = _b5.load_audio_model_nn()

# Загрузка весов аудиомоделей
url = _b5.weights_for_big5_['audio'][corpus]['hc']['sberdisk']
res_load_model_weights_hc = _b5.load_audio_model_weights_hc(url = url)

url = _b5.weights_for_big5_['audio'][corpus]['nn']['sberdisk']
res_load_model_weights_nn = _b5.load_audio_model_weights_nn(url = url)

# Формирование видеомоделей
res_load_model_hc = _b5.load_video_model_hc(lang=lang)
res_load_model_deep_fe = _b5.load_video_model_deep_fe()
res_load_model_nn = _b5.load_video_model_nn()

# Загрузка весов видеомоделей
url = _b5.weights_for_big5_['video'][corpus]['hc']['sberdisk']
res_load_model_weights_hc = _b5.load_video_model_weights_hc(url = url)

url = _b5.weights_for_big5_['video'][corpus]['fe']['sberdisk']
res_load_model_weights_deep_fe = _b5.load_video_model_weights_deep_fe(url = url)

url = _b5.weights_for_big5_['video'][corpus]['nn']['sberdisk']
res_load_model_weights_nn = _b5.load_video_model_weights_nn(url = url)

# Загрузка словаря с экспертными признаками (текстовая модальность)
res_load_text_features = _b5.load_text_features()

# Формирование текстовых моделей 
res_setup_translation_model = _b5.setup_translation_model() # только для русского языка
res_setup_translation_model = _b5.setup_bert_encoder(force_reload = False)
res_load_text_model_hc_fi = _b5.load_text_model_hc(corpus=corpus)
res_load_text_model_nn_fi = _b5.load_text_model_nn(corpus=corpus)

# Загрузка весов текстовых моделей
url = _b5.weights_for_big5_['text'][corpus]['hc']['sberdisk']
res_load_text_model_weights_hc_fi = _b5.load_text_model_weights_hc(url = url)

url = _b5.weights_for_big5_['text'][corpus]['nn']['sberdisk']
res_load_text_model_weights_nn_fi = _b5.load_text_model_weights_nn(url = url)

# Формирование модели для мультимодального объединения информации
res_load_avt_model_b5 = _b5.load_avt_model_b5()

# Загрузка весов модели для мультимодального объединения информации
url = _b5.weights_for_big5_['avt'][corpus]['b5']['sberdisk']
res_load_avt_model_weights_b5 = _b5.load_avt_model_weights_b5(url = url)

PATH_TO_DIR = './video_MuPTA/'
PATH_SAVE_VIDEO = './video_MuPTA/test/'

_b5.path_to_save_ = PATH_SAVE_VIDEO

# Загрузка 10 тестовых аудиовидеозаписей из корпуса First Impression V2
# URL: https://chalearnlap.cvc.uab.cat/dataset/24/description/
domain = 'https://download.sberdisk.ru/download/file/'
tets_name_files = [
    '477995979?token=2cvyk7CS0mHx2MJ&filename=speaker_06_center_83.mov',
    '477995980?token=jGPtBPS69uzFU6Y&filename=speaker_01_center_83.mov',
    '477995967?token=zCaRbNB6ht5wMPq&filename=speaker_11_center_83.mov',
    '477995966?token=B1rbinDYRQKrI3T&filename=speaker_15_center_83.mov',
    '477995978?token=dEpVDtZg1EQiEQ9&filename=speaker_07_center_83.mov',
    '477995961?token=o1hVjw8G45q9L9Z&filename=speaker_19_center_83.mov',
    '477995964?token=5K220Aqf673VHPq&filename=speaker_23_center_83.mov',
    '477995965?token=v1LVD2KT1cU7Lpb&filename=speaker_24_center_83.mov',
    '477995962?token=tmaSGyyWLA6XCy9&filename=speaker_27_center_83.mov',
    '477995963?token=bTpo96qNDPcwGqb&filename=speaker_10_center_83.mov',
]

for curr_files in tets_name_files:
    _b5.download_file_from_url(url = domain + curr_files, out = True)

# Получение прогнозов
_b5.path_to_dataset_ = PATH_TO_DIR # Директория набора данных
_b5.ext_ = ['.mov'] # Расширения искомых файлов

# Полный путь к файлу с верными предсказаниями для подсчета точности
url_accuracy = _b5.true_traits_['mupta']['sberdisk']

_b5.get_avt_predictions(url_accuracy = url_accuracy, lang = lang)
# Out:
# <span style="color:#666">**[</span><span style="color:#1776D2">2023-12-10 14:01:15</span><span style="color:#666">]</span> <span style="color:#666">Извлечение признаков (экспертных и нейросетевых) из текста ...</span>**
# <span style="color:#666">**[</span><span style="color:#1776D2">2023-12-10 14:01:18</span><span style="color:#666">]</span> <span style="color:#666">Получение прогнозов и вычисление точности (мультимодальное объединение) ...</span>**<p><span style="color:#666">&nbsp;&nbsp;&nbsp;&nbsp;10 из 10 (100.0%) ... GitHub\OCEANAI\docs\source\user_guide\notebooks\video_MuPTA\test\speaker_27_center_83.mov ...</span></p>
#                                                  Path  Openness  \
# ID
# 1   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.758054
# 2   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.681555
# 3   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.666224
# 4   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.694244
# 5   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.712796
# 6   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.664176
# 7   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...   0.76129
# 8   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.692825
# 9   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.706005
# 10  D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.753565
#
#    Conscientiousness Extraversion Agreeableness Neuroticism
# ID
# 1           0.692698     0.650322      0.744579    0.488338
# 2           0.654445     0.607125      0.731282    0.418026
# 3           0.656848      0.56782      0.685166    0.378143
# 4           0.596203     0.571223      0.662196    0.348687
# 5             0.5948      0.57158      0.716615    0.378084
# 6           0.670419     0.604016      0.695997    0.399863
# 7           0.652654     0.650732      0.788603    0.459695
# 8           0.683345     0.616714      0.795276    0.447282
# 9           0.658287     0.610488      0.697355    0.411963
# 10           0.70834     0.654524       0.81648    0.504736
# <span style="color:#666">**[</span><span style="color:#1776D2">2023-12-10 14:01:18</span><span style="color:#666">]</span> <span style="color:#666">Точность по отдельным персональным качествам личности человека ...</span>**
#           Openness  Conscientiousness  Extraversion  Agreeableness  \
# Metrics
# MAE         0.0673              0.079        0.1325          0.102
# Accuracy    0.9327              0.921        0.8675          0.898
#
#           Neuroticism    Mean
# Metrics
# MAE            0.1001  0.0962
# Accuracy       0.8999  0.9038
# <span style="color:#666">**[</span><span style="color:#1776D2">2023-12-10 14:01:18</span><span style="color:#666">]</span> <span style="color:#666">Средняя средних абсолютных ошибок: <span style="color:#1776D2">0.0962</span>, средняя точность: <span style="color:#1776D2">0.9038</span> ...</span>**
# <span style="color:#008001">**Лог файлы успешно сохранены ...**</span>
# <span style="color:#666">**--- Время выполнения: 300.747 сек. ---**</span>
# True

# %% [markdown]
# <hr>
#
# Для поиска подходящего коллеги по работе необходимо знать по два коэффициента корреляции для каждого персонального качества личности человека. Эти коэффициенты должны показывать как изменится оценка качества одного человека, если она будет больше или меньше оценки качества другого человека.
#
# В качестве примера предлагается использование коэффициентов корреляции между двумя людьми в контексте отношений "начальник-подчиненный", представленных в статье:
#
# 1) Kuroda S., Yamamoto I. Good boss, bad boss, workers’ mental health and productivity: Evidence from Japan // Japan & The World Economy. – 2018. – vol. 48. – pp. 106-118.
#
# Пользователь может установит свои коэффициенты корреляции.

# %%
# Загрузка датафрейма с коэффициентами корреляции
url = 'https://download.sberdisk.ru/download/file/476587839?token=o0LhzNQ5pqaoGPh&filename=colleague_ranking.csv'
df_correlation_coefficients = pd.read_csv(url)
df_correlation_coefficients = pd.DataFrame(
    df_correlation_coefficients.drop(['ID'], axis = 1)
)

df_correlation_coefficients.index.name = 'ID'
df_correlation_coefficients.index += 1
df_correlation_coefficients.index = df_correlation_coefficients.index.map(str)

df_correlation_coefficients
# Out:
#    Score_comparison  Openness  Conscientiousness  Extraversion  Agreeableness  \
# ID
# 1            higher   -0.0602             0.0471       -0.1070        -0.0832
# 2             lower   -0.1720            -0.1050        0.0772         0.0703
#
#     Neuroticism
# ID
# 1         0.190
# 2        -0.229

# %% [markdown]
# #### Поиск старшего коллеги

# %%
# Список оценок персональных качеств личности целевого человека
target_scores = [0.527886, 0.522337, 0.458468, 0.51761, 0.444649]

_b5._colleague_ranking(
    correlation_coefficients = df_correlation_coefficients,
    target_scores = target_scores,
    colleague = 'major',
    equal_coefficients = 0.5,
    out = False
)

_b5._save_logs(df = _b5.df_files_colleague_, name = 'colleague_ranking', out = True)

_b5.df_files_colleague_
# Out:
#                                                  Path  Openness  \
# ID
# 1   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.758054
# 10  D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.753565
# 8   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.692825
# 7   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...   0.76129
# 4   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.694244
# 3   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.666224
# 5   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.712796
# 6   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.664176
# 9   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.706005
# 2   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.681555
#
#    Conscientiousness Extraversion Agreeableness Neuroticism     Match
# ID
# 1           0.692698     0.650322      0.744579    0.488338 -0.051787
# 10           0.70834     0.654524       0.81648    0.504736 -0.053993
# 8           0.683345     0.616714      0.795276    0.447282 -0.056721
# 7           0.652654     0.650732      0.788603    0.459695 -0.062985
# 4           0.596203     0.571223      0.662196    0.348687 -0.209771
# 3           0.656848      0.56782      0.685166    0.378143 -0.213523
# 5             0.5948      0.57158      0.716615    0.378084 -0.222324
# 6           0.670419     0.604016      0.695997    0.399863 -0.222497
# 9           0.658287     0.610488      0.697355    0.411963 -0.229196
# 2           0.654445     0.607125      0.731282    0.418026 -0.231730

# %% [markdown]
# #### Поиск младшего коллеги

# %%
# Список оценок персональных качеств личности целевого человека
target_scores = [0.527886, 0.522337, 0.458468, 0.51761, 0.444649]

_b5._colleague_ranking(
    correlation_coefficients = df_correlation_coefficients,
    target_scores = target_scores,
    colleague = 'minor',
    equal_coefficients = 0.5,
    out = False
)

_b5._save_logs(df = _b5.df_files_colleague_, name = 'colleague_ranking', out = True)

_b5.df_files_colleague_
# Out:
#                                                  Path  Openness  \
# ID
# 2   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.681555
# 6   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.664176
# 9   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.706005
# 5   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.712796
# 3   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.666224
# 4   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.694244
# 8   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.692825
# 7   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...   0.76129
# 10  D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.753565
# 1   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.758054
#
#    Conscientiousness Extraversion Agreeableness Neuroticism     Match
# ID
# 2           0.654445     0.607125      0.731282    0.418026 -0.008253
# 6           0.670419     0.604016      0.695997    0.399863 -0.013086
# 9           0.658287     0.610488      0.697355    0.411963 -0.016115
# 5             0.5948      0.57158      0.716615    0.378084 -0.018678
# 3           0.656848      0.56782      0.685166    0.378143 -0.019660
# 4           0.596203     0.571223      0.662196    0.348687 -0.025136
# 8           0.683345     0.616714      0.795276    0.447282 -0.189797
# 7           0.652654     0.650732      0.788603    0.459695 -0.199070
# 10           0.70834     0.654524       0.81648    0.504736 -0.211693
# 1           0.692698     0.650322      0.744579    0.488338 -0.212438

# %% [markdown]
# ### `MuPTA` (en)

# %%
import os
import pandas as pd

# Импорт модуля
from oceanai.modules.lab.build import Run

# Создание экземпляра класса
_b5 = Run()

corpus = 'fi'
lang = 'en'

# Настройка ядра
_b5.path_to_save_ = './models' # Директория для сохранения файла
_b5.chunk_size_ = 2000000      # Размер загрузки файла из сети за 1 шаг

# Формирование аудиомоделей
res_load_model_hc = _b5.load_audio_model_hc()
res_load_model_nn = _b5.load_audio_model_nn()

# Загрузка весов аудиомоделей
url = _b5.weights_for_big5_['audio'][corpus]['hc']['sberdisk']
res_load_model_weights_hc = _b5.load_audio_model_weights_hc(url = url)

url = _b5.weights_for_big5_['audio'][corpus]['nn']['sberdisk']
res_load_model_weights_nn = _b5.load_audio_model_weights_nn(url = url)

# Формирование видеомоделей
res_load_model_hc = _b5.load_video_model_hc(lang=lang)
res_load_model_deep_fe = _b5.load_video_model_deep_fe()
res_load_model_nn = _b5.load_video_model_nn()

# Загрузка весов видеомоделей
url = _b5.weights_for_big5_['video'][corpus]['hc']['sberdisk']
res_load_model_weights_hc = _b5.load_video_model_weights_hc(url = url)

url = _b5.weights_for_big5_['video'][corpus]['fe']['sberdisk']
res_load_model_weights_deep_fe = _b5.load_video_model_weights_deep_fe(url = url)

url = _b5.weights_for_big5_['video'][corpus]['nn']['sberdisk']
res_load_model_weights_nn = _b5.load_video_model_weights_nn(url = url)

# Загрузка словаря с экспертными признаками (текстовая модальность)
res_load_text_features = _b5.load_text_features()

# Формирование текстовых моделей 
res_setup_translation_model = _b5.setup_translation_model() # только для русского языка
res_setup_translation_model = _b5.setup_bert_encoder(force_reload = False)
res_load_text_model_hc_fi = _b5.load_text_model_hc(corpus=corpus)
res_load_text_model_nn_fi = _b5.load_text_model_nn(corpus=corpus)

# Загрузка весов текстовых моделей
url = _b5.weights_for_big5_['text'][corpus]['hc']['sberdisk']
res_load_text_model_weights_hc_fi = _b5.load_text_model_weights_hc(url = url)

url = _b5.weights_for_big5_['text'][corpus]['nn']['sberdisk']
res_load_text_model_weights_nn_fi = _b5.load_text_model_weights_nn(url = url)

# Формирование модели для мультимодального объединения информации
res_load_avt_model_b5 = _b5.load_avt_model_b5()

# Загрузка весов модели для мультимодального объединения информации
url = _b5.weights_for_big5_['avt'][corpus]['b5']['sberdisk']
res_load_avt_model_weights_b5 = _b5.load_avt_model_weights_b5(url = url)

PATH_TO_DIR = './video_MuPTA/'
PATH_SAVE_VIDEO = './video_MuPTA/test/'

_b5.path_to_save_ = PATH_SAVE_VIDEO

# Загрузка 10 тестовых аудиовидеозаписей из корпуса First Impression V2
# URL: https://chalearnlap.cvc.uab.cat/dataset/24/description/
domain = 'https://download.sberdisk.ru/download/file/'
tets_name_files = [
    '477995979?token=2cvyk7CS0mHx2MJ&filename=speaker_06_center_83.mov',
    '477995980?token=jGPtBPS69uzFU6Y&filename=speaker_01_center_83.mov',
    '477995967?token=zCaRbNB6ht5wMPq&filename=speaker_11_center_83.mov',
    '477995966?token=B1rbinDYRQKrI3T&filename=speaker_15_center_83.mov',
    '477995978?token=dEpVDtZg1EQiEQ9&filename=speaker_07_center_83.mov',
    '477995961?token=o1hVjw8G45q9L9Z&filename=speaker_19_center_83.mov',
    '477995964?token=5K220Aqf673VHPq&filename=speaker_23_center_83.mov',
    '477995965?token=v1LVD2KT1cU7Lpb&filename=speaker_24_center_83.mov',
    '477995962?token=tmaSGyyWLA6XCy9&filename=speaker_27_center_83.mov',
    '477995963?token=bTpo96qNDPcwGqb&filename=speaker_10_center_83.mov',
]

for curr_files in tets_name_files:
    _b5.download_file_from_url(url = domain + curr_files, out = True)

# Получение прогнозов
_b5.path_to_dataset_ = PATH_TO_DIR # Директория набора данных
_b5.ext_ = ['.mov'] # Расширения искомых файлов

# Полный путь к файлу с верными предсказаниями для подсчета точности
url_accuracy = _b5.true_traits_['mupta']['sberdisk']

_b5.get_avt_predictions(url_accuracy = url_accuracy, lang = lang)
# Out:
# <span style="color:#666">**[</span><span style="color:#1776D2">2023-12-10 14:12:05</span><span style="color:#666">]</span> <span style="color:#666">Извлечение признаков (экспертных и нейросетевых) из текста ...</span>**
# <span style="color:#666">**[</span><span style="color:#1776D2">2023-12-10 14:12:06</span><span style="color:#666">]</span> <span style="color:#666">Получение прогнозов и вычисление точности (мультимодальное объединение) ...</span>**<p><span style="color:#666">&nbsp;&nbsp;&nbsp;&nbsp;10 из 10 (100.0%) ... GitHub\OCEANAI\docs\source\user_guide\notebooks\video_MuPTA\test\speaker_27_center_83.mov ...</span></p>
#                                                  Path  Openness  \
# ID
# 1   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.563529
# 2   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.648071
# 3   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.443434
# 4   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.502435
# 5   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.395977
# 6   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.563195
# 7   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.507258
# 8   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.481318
# 9   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.416557
# 10  D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.518592
#
#    Conscientiousness Extraversion Agreeableness Neuroticism
# ID
# 1           0.535709     0.437273      0.590364    0.487258
# 2           0.662212     0.600199      0.642091    0.621148
# 3           0.487488     0.319935      0.421236    0.401412
# 4           0.508988     0.415761      0.472615    0.451918
# 5           0.341571     0.325668      0.426638    0.356899
# 6            0.53541     0.489032      0.581986    0.492538
# 7           0.439226     0.430061      0.460129     0.44114
# 8           0.520708     0.307745       0.43555    0.435151
# 9           0.469524     0.324863      0.447565    0.412865
# 10          0.669341      0.43365       0.55932    0.552231
# <span style="color:#666">**[</span><span style="color:#1776D2">2023-12-10 14:12:06</span><span style="color:#666">]</span> <span style="color:#666">Точность по отдельным персональным качествам личности человека ...</span>**
#           Openness  Conscientiousness  Extraversion  Agreeableness  \
# Metrics
# MAE         0.1729             0.1679        0.1664         0.2554
# Accuracy    0.8271             0.8321        0.8336         0.7446
#
#           Neuroticism   Mean
# Metrics
# MAE            0.1074  0.174
# Accuracy       0.8926  0.826
# <span style="color:#666">**[</span><span style="color:#1776D2">2023-12-10 14:12:06</span><span style="color:#666">]</span> <span style="color:#666">Средняя средних абсолютных ошибок: <span style="color:#1776D2">0.174</span>, средняя точность: <span style="color:#1776D2">0.826</span> ...</span>**
# <span style="color:#008001">**Лог файлы успешно сохранены ...**</span>
# <span style="color:#666">**--- Время выполнения: 276.636 сек. ---**</span>
# True

# %% [markdown]
# <hr>
#
# Для поиска подходящего коллеги по работе необходимо знать по два коэффициента корреляции для каждого персонального качества личности человека. Эти коэффициенты должны показывать как изменится оценка качества одного человека, если она будет больше или меньше оценки качества другого человека.
#
# В качестве примера предлагается использование коэффициентов корреляции между двумя людьми в контексте отношений "начальник-подчиненный", представленных в статье:
#
# 1) Kuroda S., Yamamoto I. Good boss, bad boss, workers’ mental health and productivity: Evidence from Japan // Japan & The World Economy. – 2018. – vol. 48. – pp. 106-118.
#
# Пользователь может установит свои коэффициенты корреляции.

# %%
# Загрузка датафрейма с коэффициентами корреляции
url = 'https://download.sberdisk.ru/download/file/476587839?token=o0LhzNQ5pqaoGPh&filename=colleague_ranking.csv'
df_correlation_coefficients = pd.read_csv(url)
df_correlation_coefficients = pd.DataFrame(
    df_correlation_coefficients.drop(['ID'], axis = 1)
)

df_correlation_coefficients.index.name = 'ID'
df_correlation_coefficients.index += 1
df_correlation_coefficients.index = df_correlation_coefficients.index.map(str)

df_correlation_coefficients
# Out:
#    Score_comparison  Openness  Conscientiousness  Extraversion  Agreeableness  \
# ID
# 1            higher   -0.0602             0.0471       -0.1070        -0.0832
# 2             lower   -0.1720            -0.1050        0.0772         0.0703
#
#     Neuroticism
# ID
# 1         0.190
# 2        -0.229

# %% [markdown]
# #### Поиск старшего коллеги

# %%
# Список оценок персональных качеств личности целевого человека
target_scores = [0.527886, 0.522337, 0.458468, 0.51761, 0.444649]

_b5._colleague_ranking(
    correlation_coefficients = df_correlation_coefficients,
    target_scores = target_scores,
    colleague = 'major',
    equal_coefficients = 0.5,
    out = False
)

_b5._save_logs(df = _b5.df_files_colleague_, name = 'colleague_ranking', out = True)

_b5.df_files_colleague_
# Out:
#                                                  Path  Openness  \
# ID
# 1   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.563529
# 10  D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.518592
# 4   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.502435
# 2   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.648071
# 6   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.563195
# 5   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.395977
# 9   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.416557
# 3   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.443434
# 7   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.507258
# 8   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.481318
#
#    Conscientiousness Extraversion Agreeableness Neuroticism     Match
# ID
# 1           0.535709     0.437273      0.590364    0.487258  0.068536
# 10          0.669341      0.43365       0.55932    0.552231  0.034223
# 4           0.508988     0.415761      0.472615    0.451918  0.011344
# 2           0.662212     0.600199      0.642091    0.621148 -0.007446
# 6            0.53541     0.489032      0.581986    0.492538 -0.015873
# 5           0.341571     0.325668      0.426638    0.356899 -0.130585
# 9           0.469524     0.324863      0.447565    0.412865 -0.158929
# 3           0.487488     0.319935      0.421236    0.401412 -0.165067
# 7           0.439226     0.430061      0.460129     0.44114 -0.168841
# 8           0.520708     0.307745       0.43555    0.435151 -0.182737

# %% [markdown]
# #### Поиск младшего коллеги

# %%
# Список оценок персональных качеств личности целевого человека
target_scores = [0.527886, 0.522337, 0.458468, 0.51761, 0.444649]

_b5._colleague_ranking(
    correlation_coefficients = df_correlation_coefficients,
    target_scores = target_scores,
    colleague = 'minor',
    equal_coefficients = 0.5,
    out = False
)

_b5._save_logs(df = _b5.df_files_colleague_, name = 'colleague_ranking', out = True)

_b5.df_files_colleague_
# Out:
#                                                  Path  Openness  \
# ID
# 8   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.481318
# 9   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.416557
# 3   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.443434
# 5   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.395977
# 7   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.507258
# 6   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.563195
# 4   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.502435
# 2   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.648071
# 10  D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.518592
# 1   D:\GitHub\OCEANAI\docs\source\user_guide\noteb...  0.563529
#
#    Conscientiousness Extraversion Agreeableness Neuroticism     Match
# ID
# 8           0.520708     0.307745       0.43555    0.435151  0.009103
# 9           0.469524     0.324863      0.447565    0.412865  0.003476
# 3           0.487488     0.319935      0.421236    0.401412  0.003273
# 5           0.341571     0.325668      0.426638    0.356899 -0.010269
# 7           0.439226     0.430061      0.460129     0.44114 -0.010351
# 6            0.53541     0.489032      0.581986    0.492538 -0.187124
# 4           0.508988     0.415761      0.472615    0.451918 -0.193582
# 2           0.662212     0.600199      0.642091    0.621148 -0.231733
# 10          0.669341      0.43365       0.55932    0.552231 -0.235063
# 1           0.535709     0.437273      0.590364    0.487258 -0.270039
